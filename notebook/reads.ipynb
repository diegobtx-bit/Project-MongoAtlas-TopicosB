# %%
from connect import db
from bson.objectid import ObjectId

libros = db.libros

#Encontrar todas las colecciones
for doc in libros. find():
    print(doc)
# Out:
# {'_id': ObjectId('690df515c4c48afac2a0c128'), 'titulo': 'La casa Verde', 'autor': 'Mario Vargas Llosa', 'anio': 1965, 'categorias': ['novela', 'ficcion'], 'stock': 4}
# {'_id': ObjectId('690df6c9c4c48afac2a0c129'), 'titulo': 'Don Quijote', 'autor': 'Miguel de Cervantes Saavedra', 'anio': 1965, 'categorias': ['clasico', 'ficcion'], 'stock': 5}
# {'_id': ObjectId('690df6c9c4c48afac2a0c12a'), 'titulo': 'La ciudad y los perros', 'autor': 'Mario Vargas Llosa', 'anio': 1963, 'categorias': ['novela'], 'stock': 3}
# {'_id': ObjectId('690df72ec4c48afac2a0c12b'), 'titulo': '1984', 'autor': 'George Orwell', 'anio': 1949, 'generos': ['distopía', 'ciencia ficción', 'política'], 'prestado': True, 'editorial': {'nombre': 'Secker & Warburg', 'pais': 'Reino Unido'}}
# {'_id': ObjectId('690df72ec4c48afac2a0c12c'), 'titulo': 'Fahrenheit 451', 'autor': 'Ray Bradbury', 'anio': 1953, 'generos': ['ciencia ficción', 'distopía'], 'prestado': False, 'editorial': {'nombre': 'Ballantine Books', 'pais': 'EE.UU.'}}
# {'_id': ObjectId('690df72ec4c48afac2a0c12d'), 'titulo': 'El nombre del viento', 'autor': 'Patrick Rothfuss', 'anio': 2007, 'generos': ['fantasía', 'aventura'], 'prestado': True}
# {'_id': ObjectId('690df72ec4c48afac2a0c12e'), 'titulo': 'Dune', 'autor': 'Frank Herbert', 'anio': 1965, 'generos': ['ciencia ficción', 'política', 'religión'], 'prestado': False, 'editorial': {'nombre': 'Chilton Books', 'pais': 'EE.UU.'}}
# {'_id': ObjectId('690df72ec4c48afac2a0c12f'), 'titulo': 'Orgullo y prejuicio', 'autor': 'Jane Austen', 'anio': 1813, 'generos': ['romance', 'clásico'], 'prestado': False}
# {'_id': ObjectId('690df72ec4c48afac2a0c130'), 'titulo': 'El resplandor', 'autor': 'Stephen King', 'anio': 1977, 'generos': ['terror', 'suspense'], 'prestado': True}
# {'_id': ObjectId('690df72ec4c48afac2a0c131'), 'titulo': 'Neuromante', 'autor': 'William Gibson', 'anio': 1984, 'generos': ['ciencia ficción', 'ciberpunk'], 'prestado': False}
# {'_id': ObjectId('690df72ec4c48afac2a0c132'), 'titulo': 'Crónicas marcianas', 'autor': 'Ray Bradbury', 'anio': 1950, 'generos': ['ciencia ficción', 'cuentos'], 'prestado': True}
# {'_id': ObjectId('690df72ec4c48afac2a0c133'), 'titulo': 'Cien años de soledad', 'autor': 'Gabriel García Márquez', 'anio': 1967, 'generos': ['realismo mágico', 'novela'], 'prestado': False, 'editorial': {'nombre': 'Sudamericana', 'pais': 'Argentina'}}
# {'_id': ObjectId('690df72ec4c48afac2a0c134'), 'titulo': 'El código Da Vinci', 'autor': 'Dan Brown', 'anio': 2003, 'generos': ['misterio', 'thriller'], 'prestado': True}
# {'_id': ObjectId('690df72ec4c48afac2a0c135'), 'titulo': 'Matar un ruiseñor', 'autor': 'Harper Lee', 'anio': 1960, 'generos': ['drama', 'clásico'], 'prestado': False}
# {'_id': ObjectId('690df72ec4c48afac2a0c136'), 'titulo': 'La ladrona de libros', 'autor': 'Markus Zusak', 'anio': 2005, 'generos': ['histórica', 'drama'], 'prestado': True}
# {'_id': ObjectId('690df72ec4c48afac2a0c137'), 'titulo': 'Fundación', 'autor': 'Isaac Asimov', 'anio': 1951, 'generos': ['ciencia ficción', 'space opera'], 'prestado': False}
# {'_id': ObjectId('690df72ec4c48afac2a0c138'), 'titulo': 'El hobbit', 'autor': 'J.R.R. Tolkien', 'anio': 1937, 'generos': ['fantasía', 'aventura'], 'prestado': True}
# {'_id': ObjectId('690df72ec4c48afac2a0c139'), 'titulo': 'Rebelión en la granja', 'autor': 'George Orwell', 'anio': 1945, 'generos': ['satira', 'política', 'clásico'], 'prestado': False}
# {'_id': ObjectId('690df72ec4c48afac2a0c13a'), 'titulo': 'El perfume', 'autor': 'Patrick Süskind', 'anio': 1985, 'generos': ['histórica', 'drama', 'misterio'], 'prestado': True}
# {'_id': ObjectId('690df72ec4c48afac2a0c13b'), 'titulo': 'Sapiens: De animales a dioses', 'autor': 'Yuval Noah Harari', 'anio': 2011, 'generos': ['ensayo', 'historia', 'no ficción'], 'prestado': False}
# {'_id': ObjectId('690df72ec4c48afac2a0c13c'), 'titulo': 'El alquimista', 'autor': 'Paulo Coelho', 'anio': 1988, 'generos': ['filosófica', 'aventura'], 'prestado': True}
# {'_id': ObjectId('690df72ec4c48afac2a0c13d'), 'titulo': 'Blade Runner (¿Sueñan los androides con ovejas eléctricas?)', 'autor': 'Philip K. Dick', 'anio': 1968, 'generos': ['ciencia ficción', 'filosófica'], 'prestado': False}
# {'_id': ObjectId('690df72ec4c48afac2a0c13e'), 'titulo': 'Cumbres borrascosas', 'autor': 'Emily Brontë', 'anio': 1847, 'generos': ['romance', 'gótico', 'clásico'], 'prestado': True}

# %%
#Filtro con where

for doc in libros.find({'autor':'Mario Vargas Llosa'}):
    print(doc['titulo'], doc['anio'])
# Out:
# La casa Verde 1965
# La ciudad y los perros 1963
